# 989           0.0         0.014539        0.0
# 990           0.0         0.014539        0.0
# 991           0.0         0.014539        0.0
# 992           0.0         0.014539        0.0
# 993           0.0         0.014539        0.0
# 994           0.0         0.014539        0.0
# 995           0.0         0.014539        0.0
# 996           0.0         0.014539        0.0
# 997           0.0         0.014539        0.0
# 998           0.0         0.014539        0.0
# 999           0.0         0.014539        0.0
# 1000          0.0         0.014539        0.0
#
# [1001 rows x 8 columns]

# %%
list(mydata[0]) == ['Frequency (Hz)',
 'S21re ()',
 'S21im ()',
 'S21dB (dB)',
 'S21Ph (rad)',
 'Power (dBm)',
 'Temperature (K)',
 'Power (K)']
# Out:
# True

# %%
mydata[0].shape
# Out:
# (1001, 8)

# %%
datavna = mydata[-1]

# %%
#************************************************
fitwidth = 5.  #Width of trace to fit in units of detected peak width
trimwidth = 3.  #Width to trim around detected peak for background fit in units of detected peak width
ftype = 'A'  # A and -A are reflection models while B and -B are side coupled models
doplots = False  #Show debugging plots
margin = 51  #smoothing margin for peak detection
#************************************************

# %%
#*************************** DO FIT AND RETURN RESULT *********************************************************
z = datavna['S21re ()'] + 1j * datavna['S21im ()']  #Convert S parameter data from Re,Im to complex array
x = datavna['Frequency (Hz)']
fitres, _, _, _ = stanalysis.S11fit(x,z)#,ftype=ftype,doplots=doplots,trimwidth=trimwidth,fitwidth=fitwidth,margin=margin)  #Do fit with some given parameters.  More options available.
fnew = fitres['f0'].value
# Out:
# Max index:  496  Max frequency:  8108800000.0
# Peak limits:  471 523
# Lower edge:  8107550000.0  Center:  8108800000.0  Upper edge:  8110150000.0  Points in width:  52
# 1001 1001
# 1.3367331689097224 -1.5907276447182692e-10 3148.757172395393 -3.8944985581596414e-07
# [[Variables]]
#     a:   232.641069 +/- 16.4526666 (7.07%) (init = 1.336733)
#     b:  -5.7207e-08 +/- 4.0579e-09 (7.09%) (init = -1.590728e-10)
#     c:   3.5176e-18 +/- 2.5021e-19 (7.11%) (init = 0)
#     ap:  3110.33112 +/- 0.26584582 (0.01%) (init = 3148.757)
#     bp: -3.8470e-07 +/- 3.2792e-11 (0.01%) (init = -3.894499e-07)
#     cp:  0 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(b, c)   = -1.000
#     C(a, b)   = -1.000
#     C(a, c)   =  1.000
#     C(ap, bp) = -1.000
# [[Variables]]
#     a:      232.6411 (fixed)
#     b:     -5.720749e-08 (fixed)
#     c:      3.51764e-18 (fixed)
#     ap:     3110.331 (fixed)
#     bp:    -3.847013e-07 (fixed)
#     cp:     0 (fixed)
#     Qint:   69089.5886 +/- 1872.45929 (2.71%) (init = 19640.33)
#     Qext:   11014.6780 +/- 41.0665964 (0.37%) (init = 3707.498)
#     f0:     8.1089e+09 +/- 2239.10690 (0.00%) (init = 8.1088e+09)
#     theta: -0.05308760 +/- 0.00372836 (7.02%) (init = 0)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(f0, theta)  = -0.711
#     C(Qint, Qext) =  0.138
# QLoaded =  9500.112859456967
# [[Variables]]
#     a:      225.420023 +/- 4.82386279 (2.14%) (init = 232.6411)
#     b:     -5.5420e-08 +/- 1.1898e-09 (2.15%) (init = -5.720749e-08)
#     c:      3.4070e-18 +/- 7.3360e-20 (2.15%) (init = 3.51764e-18)
#     ap:     3127.41832 +/- 0.14699293 (0.00%) (init = 3110.331)
#     bp:    -3.8681e-07 +/- 1.8130e-11 (0.00%) (init = -3.847013e-07)
#     cp:     0 (fixed)
#     Qint:   66386.3992 +/- 650.267382 (0.98%) (init = 69089.59)
#     Qext:   10594.1855 +/- 14.1004506 (0.13%) (init = 11014.68)
#     f0:     8.1089e+09 +/- 827.650340 (0.00%) (init = 8.108897e+09)
#     theta: -0.05468330 +/- 0.00133101 (2.43%) (init = -0.0530876)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a, b)       = -1.000
#     C(b, c)       = -1.000
#     C(a, c)       =  1.000
#     C(ap, bp)     = -1.000
#     C(f0, theta)  = -0.718
#     C(ap, Qext)   = -0.256
#     C(bp, Qext)   =  0.256
#     C(c, Qint)    =  0.228
#     C(b, Qint)    = -0.228
#     C(a, Qint)    =  0.228
#     C(Qint, Qext) =  0.151
# QLoaded =  9136.197550327975
# /home/feschmidt/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
fitres
# Out:
# Parameters([('a',
#              <Parameter 'a', value=225.42002297674847 +/- 4.82, bounds=[-inf:inf]>),
#             ('b',
#              <Parameter 'b', value=-5.5419709178623445e-08 +/- 1.19e-09, bounds=[-inf:inf]>),
#             ('c',
#              <Parameter 'c', value=3.406987844228976e-18 +/- 7.34e-20, bounds=[-inf:inf]>),
#             ('ap',
#              <Parameter 'ap', value=3127.4183214034797 +/- 0.147, bounds=[-inf:inf]>),
#             ('bp',
#              <Parameter 'bp', value=-3.8680965242502617e-07 +/- 1.81e-11, bounds=[-inf:inf]>),
#             ('cp', <Parameter 'cp', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('Qint',
#              <Parameter 'Qint', value=66386.39921861752 +/- 650, bounds=[0:inf]>),
#             ('Qext',
#              <Parameter 'Qext', value=10594.18552672409 +/- 14.1, bounds=[0:inf]>),
#             ('f0',
#              <Parameter 'f0', value=8108901094.570897 +/- 828, bounds=[-inf:inf]>),
#             ('theta',
#              <Parameter 'theta', value=-0.05468329514895939 +/- 0.00133, bounds=[-inf:inf]>)])

# %%
zfit = stanalysis.S11func(datavna['Frequency (Hz)'],fitres,ftype='A')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(datavna['Frequency (Hz)'],datavna['S21dB (dB)'])
plt.plot(datavna['Frequency (Hz)'],20*np.log10(np.abs(zfit)))
plt.show()
plt.close()

# %%
np.sqrt(np.sum((thedata-thefit)**2))
# Out:
# 0.7210455019172353

# %%
freqs = datavna['Frequency (Hz)']
thedata = datavna['S21dB (dB)']
thefit = 20*np.log10(np.abs(zfit))

plt.plot(freqs,thedata-thefit)
plt.show()
plt.close()

# %%
ress = stanalysis.utils.S11fit.S11residual(fitres,datavna['Frequency (Hz)'],datavna['S21dB (dB)'])

# %%
reress=ress[::2]
imress=ress[1::2]
theress=np.abs(reress+1j*imress)

# %%
plt.plot(datavna['Frequency (Hz)'],theress)
plt.show()
plt.close()

# %%
plt.plot(datavna['Frequency (Hz)'],imress)
plt.show()
plt.close()

# %%
plt.plot(datavna['Frequency (Hz)'],reress)
plt.show()
plt.close()
